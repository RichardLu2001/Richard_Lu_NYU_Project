# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
import lightgbm as lgb
import optuna
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# %%
df = pd.read_pickle('My Data.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4129 entries, 2009-01-02 to 2025-06-02
# Columns: 458 entries, BDI to curvature
# dtypes: float64(450), int32(5), int64(3)
# memory usage: 14.4 MB

# %%
df['month'] = df['month'].astype('category')
df['Recession'] = df['Recession'].astype('category')
df['steepen'] = df['steepen'].astype('category')
df['curvature'] = df['curvature'].astype('category')
df['steepen_2week'] = df['steepen_2week'].astype('category')
df['curvature_2week'] = df['curvature_2week'].astype('category')

df.drop(['infl_a_reverse','infl_m_reverse','infl_q_reverse'], axis=1, inplace=True)

# %% [markdown]
# <font size=4, font color='blue'> Rolling window percentile scaler

# %%
window = int(2 * 252)

to_transform = df.select_dtypes(include='number').columns

df_pct = df.copy()
for col in to_transform:
    df_pct[col] = (
        df[col]
        .rolling(window=window, min_periods=1)
        .apply(lambda x: pd.Series(x).rank(pct=True).iloc[-1], raw=False)
    )

df_pct = df_pct.loc['2010-01-01':'2025-05-30']

df_pct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3876 entries, 2010-01-04 to 2025-05-30
# Columns: 455 entries, BDI to curvature
# dtypes: category(6), float64(449)
# memory usage: 13.3 MB

# %%
df_pct
# Out:
#                  BDI     BDI_7    BDI_14    BDI_21  BDI_pct7  BDI_pct14  \
# 2010-01-04  0.687747  0.766798  0.916996  0.948617  0.213439   0.098814
# 2010-01-05  0.720472  0.740157  0.889764  0.921260  0.370079   0.192913
# 2010-01-06  0.717647  0.705882  0.870588  0.909804  0.474510   0.223529
# 2010-01-07  0.683594  0.679688  0.832031  0.902344  0.457031   0.222656
# 2010-01-08  0.678988  0.665370  0.817121  0.910506  0.533074   0.249027
# ...              ...       ...       ...       ...       ...        ...
# 2025-05-23  0.321429  0.281746  0.371032  0.291667  0.666667   0.408730
# 2025-05-27  0.301587  0.309524  0.361111  0.303571  0.454365   0.375000
# 2025-05-28  0.309524  0.355159  0.324405  0.313492  0.319444   0.416667
# 2025-05-29  0.334325  0.323413  0.303571  0.343254  0.484127   0.539683
# 2025-05-30  0.390873  0.318452  0.299603  0.334325  0.668651   0.686508
#
#             BDI_pct21    BDI_42  BDI_mean7  BDI_mean14  ...  SP400_ret_std14  \
# 2010-01-04   0.122530  0.774704   0.667984    0.762846  ...         0.047431
# 2010-01-05   0.165354  0.789370   0.657480    0.732283  ...         0.027559
# 2010-01-06   0.184314  0.819608   0.658824    0.709804  ...         0.023529
# 2010-01-07   0.164062  0.828125   0.652344    0.679688  ...         0.023438
# 2010-01-08   0.155642  0.832685   0.665370    0.673152  ...         0.011673
# ...               ...       ...        ...         ...  ...              ...
# 2025-05-23   0.581349  0.544643   0.319444    0.297619  ...         0.825397
# 2025-05-27   0.462302  0.549603   0.319444    0.289683  ...         0.902778
# 2025-05-28   0.450397  0.539683   0.311508    0.287698  ...         0.924603
# 2025-05-29   0.476190  0.530754   0.313492    0.291667  ...         0.918651
# 2025-05-30   0.555556  0.519841   0.323413    0.297619  ...         0.918651
#
#             SP400_pct21  SP400_ret_std21  SP400_pct42  SP400_ret_std42  month  \
# 2010-01-04     0.644269         0.015810     0.731225         0.007905      1
# 2010-01-05     0.740157         0.011811     0.692913         0.007874      1
# 2010-01-06     0.694118         0.003922     0.733333         0.007843      1
# 2010-01-07     0.718750         0.003906     0.652344         0.003906      1
# 2010-01-08     0.793774         0.003891     0.688716         0.003891      1
# ...                 ...              ...          ...              ...    ...
# 2025-05-23     0.769841         0.753968     0.299603         0.962302      5
# 2025-05-27     0.910714         0.823413     0.507937         0.978175      5
# 2025-05-28     0.837302         0.849206     0.456349         0.982143      5
# 2025-05-29     0.817460         0.847222     0.634921         0.964286      5
# 2025-05-30     0.793651         0.857143     0.579365         0.964286      5
#
#             steepen_2week  curvature_2week  steepen  curvature
# 2010-01-04              1                0        1          0
# 2010-01-05              1                0        1          0
# 2010-01-06              0                0        0          0
# 2010-01-07              0                0        1          0
# 2010-01-08              0                0        0          0
# ...                   ...              ...      ...        ...
# 2025-05-23              0                1        1          1
# 2025-05-27              0                1        1          1
# 2025-05-28              0                0        1          0
# 2025-05-29              0                0        1          0
# 2025-05-30              0                0        0          0
#
# [3876 rows x 455 columns]

# %%
df_pct.to_pickle('My Data Percentile.pkl')

# %% [markdown]
# <font size=4, font color='blue'> 8:2 Train-test split, no shuffling

# %%
target = 'steepen'
X = df_pct.drop(columns=[target,'curvature','steepen_2week','curvature_2week'])
y = df_pct[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %% [markdown]
# <font size=4, font color='blue'> Use correlation matrix to find out strongly-correlated feature pairs

# %%
corr_matrix = X_train.corr()

mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
upper_corr = corr_matrix.where(mask)

threshold = 0.95
high_corr_pairs = (
    upper_corr
    .stack()                                 
    .rename("corr")                         
    .reset_index()                         
    .query("abs(corr) >= @threshold")       
)
high_corr_pairs.columns = ["feature_1", "feature_2", "corr_value"]

# %%
high_corr_pairs.sort_values(by=['corr_value'], ascending=False)
# Out:
#              feature_1       feature_2  corr_value
# 26787       CRB_mean14      CRB_mean21    0.995931
# 457              BDI_7      BDI_mean14    0.994987
# 25233        CRB_mean7      CRB_mean14    0.994020
# 24452         CRB_lag7      CRB_mean14    0.993897
# 85725       USD_mean14      USD_mean21    0.993769
# ...                ...             ...         ...
# 15984    HY-IG Spread7  HY-IG Spread14    0.951134
# 101215   Russell_pct14     SP400_pct14    0.950977
# 15570     HY-IG Spread   HY-IG Spread7    0.950693
# 899             BDI_14          BDI_21    0.950176
# 82173   SPY_vol_mean14  SPY_vol_mean21    0.950088
#
# [79 rows x 3 columns]

# %%
def select_redundant_features(high_corr_pairs, threshold=0.9):
    to_remove = []
    for _, row in high_corr_pairs.iterrows():
        f1, f2, corr = row['feature_1'], row['feature_2'], row['corr_value']
        if abs(corr) < threshold:
            continue
        if f1 not in to_remove and f2 not in to_remove:
            to_remove.append(f2)
    return to_remove

# %% [markdown]
# <font size=4, font color='blue'> For pairs with correlation>0.95, drop one of them

# %%
to_drop = select_redundant_features(high_corr_pairs, threshold=0.95)
to_drop
# Out:
# ['BDI_mean7',
#  'BDI_mean14',
#  'BDI_mean21',
#  'BDI_21',
#  'BDI_mean42',
#  'HY-IG Spread',
#  'Investment Grade OAS7',
#  'HY-IG Spread14',
#  'Investment Grade OAS21',
#  'CRB_lag7',
#  'CRB_mean7',
#  'CRB_mean14',
#  'CRB_mean21',
#  'CRB_lag21',
#  'CRB_mean42',
#  'level_diff21',
#  'EPU_mean21',
#  'Industry_Production_Index1',
#  'MOVE_mean7',
#  'MOVE_mean21',
#  'MOVE7',
#  'P/C_Index_mean21',
#  'VIX_mean14',
#  'VVIX_mean21',
#  'SPY_vol_mean21',
#  'USD_mean7',
#  'USD_mean14',
#  'USD_mean21',
#  'USD_mean42',
#  'TPU_mean21',
#  'oil_vol_mean21',
#  'SP400_pct7',
#  'SP400_pct14']

# %%
X_train = X_train[[col for col in X_train.columns.tolist() if col not in to_drop]]
X_test = X_test[[col for col in X_test.columns.tolist() if col not in to_drop]]

# %% [markdown]
# <font size=4, font color='blue'> Inspect VIF of remaining features

# %%
X = X_train.ffill()

vif_df = pd.DataFrame()
vif_df['feature'] = X.columns
vif_df['VIF'] = [
    variance_inflation_factor(X.values, i)
    for i in range(X.shape[1])
]

vif_df['high_vif'] = vif_df['VIF'] > 10

vif_df = vif_df.sort_values('VIF', ascending=False).reset_index(drop=True)

print(vif_df)
# Out:
#               feature         VIF  high_vif
# 0               10 Yr  697.141283      True
# 1        10 Yr_diff21  594.878544      True
# 2    Bull_Bear_Spread  553.858877      True
# 3               level  448.664949      True
# 4                5 Yr  418.201320      True
# ..                ...         ...       ...
# 413   investment_pct7    9.860303     False
# 414   employment_pct7    9.421336     False
# 415      savings_pct7    8.883958     False
# 416     shopping_pct7    8.483926     False
# 417         Recession    6.023088     False
#
# [418 rows x 3 columns]

# %% [markdown]
# <font size=4, font color='blue'> Recursive Feature Elimination using a LightGBM model's feature importance scores

# %%
def recursive_rfe(
    X, y,
    eliminate_per_round: int = 20,
    target_features: int = 100,
    lgbm_params: dict = None,
    random_state: int = 42
):
    if lgbm_params is None:
        lgbm_params = {
          'objective':        'binary',
          'is_unbalance':     True,
          'n_estimators':     100,
          'learning_rate':    0.1,
          'subsample':        0.8,
          'colsample_bytree': 0.7,
          'subsample_freq':   1,
          'reg_alpha':        0.0,
          'reg_lambda':       0.5,
          'random_state':     random_state,
          'verbose':          -1,
          'n_jobs':           -1
        }

    history = []
    X_curr = X.copy()
    while X_curr.shape[1] > target_features:
        model = lgb.LGBMClassifier(**lgbm_params)
        model.fit(X_curr, y)
        
        imp_df = pd.DataFrame({
            'feature': X_curr.columns,
            'importance': model.feature_importances_
        }).set_index('feature').sort_values('importance', ascending=False)
        history.append(imp_df)

        n_drop = min(eliminate_per_round, X_curr.shape[1] - target_features)
        to_drop = imp_df.tail(n_drop).index.tolist()

        X_curr = X_curr.drop(columns=to_drop)
        print(f"Dropped {len(to_drop)} features; {X_curr.shape[1]} remain.")

    model = lgb.LGBMClassifier(**lgbm_params)
    model.fit(X_curr, y)
    final_imp = pd.DataFrame({
        'feature': X_curr.columns,
        'importance': model.feature_importances_
    }).set_index('feature').sort_values('importance', ascending=False)
    history.append(final_imp)

    return X_curr.columns.tolist(), history

# %%
selected_feats, rfe_history = recursive_rfe(
    X_train.ffill(), y_train,
    eliminate_per_round=5,
    target_features=40,
    random_state=42
)

print("Final features:", selected_feats)
# Out:
# Dropped 5 features; 413 remain.
# Dropped 5 features; 408 remain.
# Dropped 5 features; 403 remain.
# Dropped 5 features; 398 remain.
# Dropped 5 features; 393 remain.
# Dropped 5 features; 388 remain.
# Dropped 5 features; 383 remain.
# Dropped 5 features; 378 remain.
# Dropped 5 features; 373 remain.
# Dropped 5 features; 368 remain.
# Dropped 5 features; 363 remain.
# Dropped 5 features; 358 remain.
# Dropped 5 features; 353 remain.
# Dropped 5 features; 348 remain.
# Dropped 5 features; 343 remain.
# Dropped 5 features; 338 remain.
# Dropped 5 features; 333 remain.
# Dropped 5 features; 328 remain.
# Dropped 5 features; 323 remain.
# Dropped 5 features; 318 remain.
# Dropped 5 features; 313 remain.
# Dropped 5 features; 308 remain.
# Dropped 5 features; 303 remain.
# Dropped 5 features; 298 remain.
# Dropped 5 features; 293 remain.
# Dropped 5 features; 288 remain.
# Dropped 5 features; 283 remain.
# Dropped 5 features; 278 remain.
# Dropped 5 features; 273 remain.
# Dropped 5 features; 268 remain.
# Dropped 5 features; 263 remain.
# Dropped 5 features; 258 remain.
# Dropped 5 features; 253 remain.
# Dropped 5 features; 248 remain.
# Dropped 5 features; 243 remain.
# Dropped 5 features; 238 remain.
# Dropped 5 features; 233 remain.
# Dropped 5 features; 228 remain.
# Dropped 5 features; 223 remain.
# Dropped 5 features; 218 remain.
# Dropped 5 features; 213 remain.
# Dropped 5 features; 208 remain.
# Dropped 5 features; 203 remain.
# Dropped 5 features; 198 remain.
# Dropped 5 features; 193 remain.
# Dropped 5 features; 188 remain.
# Dropped 5 features; 183 remain.
# Dropped 5 features; 178 remain.
# Dropped 5 features; 173 remain.
# Dropped 5 features; 168 remain.
# Dropped 5 features; 163 remain.
# Dropped 5 features; 158 remain.
# Dropped 5 features; 153 remain.
# Dropped 5 features; 148 remain.
# Dropped 5 features; 143 remain.
# Dropped 5 features; 138 remain.
# Dropped 5 features; 133 remain.
# Dropped 5 features; 128 remain.
# Dropped 5 features; 123 remain.
# Dropped 5 features; 118 remain.
# Dropped 5 features; 113 remain.
# Dropped 5 features; 108 remain.
# Dropped 5 features; 103 remain.
# Dropped 5 features; 98 remain.
# Dropped 5 features; 93 remain.
# Dropped 5 features; 88 remain.
# Dropped 5 features; 83 remain.
# Dropped 5 features; 78 remain.
# Dropped 5 features; 73 remain.
# Dropped 5 features; 68 remain.
# Dropped 5 features; 63 remain.
# Dropped 5 features; 58 remain.
# Dropped 5 features; 53 remain.
# Dropped 5 features; 48 remain.
# Dropped 5 features; 43 remain.
# Dropped 3 features; 40 remain.
# Final features: ['BDI_pct7', 'BDI_pct21', 'Bond_pct7', 'Bond_pct14', 'Bond_ret_std14', 'Investment Grade OAS14', 'infl_a', 'infl_a3', 'infl_q_diff', '5 Yr', 'level', '10Y-2Y', '10Y-2Y_diff21', 'EPU_mean42', 'GSCPI_diff2', 'shopping_pct14', 'Industry_Production_Index_pct2', 'Bullish_mean4', 'Bullish_std8', 'P/C_Equity_mean14', 'P/C_Equity_std21', 'P/C_Index_pct21', 'VIX_std21', 'VVIX_mean42', 'TPU_pct42', 'gold_vol_mean21', 'gold_pct42', 'gold_vol_std42', 'silver_std21', 'silver_std42', 'oil_vol_std42', 'oil_vol_mean42', 'n_gas_vol_pct14', 'n_gas_vol_std42', 'soybean_std7', 'soybean_vol_std14', 'soybean_vol_mean21', 'soybean_vol_std42', 'copper_vol_mean42', 'Russell_vol_std42']

# %%
sorted(rfe_history[-1].index.tolist()) == sorted(selected_feats)
# Out:
# True

# %% [markdown]
# <font size=4, font color='blue'> Expanding window purged CV and Optuna (Bayesian optimizer) for hyperparameter optimization

# %%
def expanding_window_cv(X, y, init_frac, val_frac, n_folds, lgb_params, random_state=42):
    n = len(y)
    init_window = int(np.floor(init_frac * n))
    val_window  = int(np.floor(val_frac  * n))
    aucs = []

    for fold in range(n_folds):
        train_end = init_window + fold * val_window
        val_start = train_end
        val_end   = val_start + val_window
        if val_end > n:
            break

        X_tr, y_tr = X[:train_end-63], y[:train_end-63]
        X_val, y_val = X[val_start:val_end], y[val_start:val_end]

        clf = lgb.LGBMClassifier(random_state=random_state, **lgb_params)
        clf.fit(X_tr, y_tr)
        y_proba = clf.predict_proba(X_val)[:, 1]
        aucs.append(roc_auc_score(y_val, y_proba))

    return np.mean(aucs)


def objective(trial):

    max_depth = trial.suggest_int('max_depth', 5, 15)
    max_leaves = min(2 ** max_depth, 200)
    num_leaves = trial.suggest_int('num_leaves', 20, max_leaves)


    param = {
        'objective': 'binary',
        'is_unbalance': True,
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3),
        'num_leaves': num_leaves,
        'max_depth': max_depth,
        'subsample': trial.suggest_float('subsample', 0.7, 0.9),
        'subsample_freq': 1,
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 0.9),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 10.0),
        'n_jobs': -1
    }
    
    mean_auc = expanding_window_cv(
        X_train[selected_feats].ffill(),
        y_train,
        init_frac=0.30,
        val_frac=0.14,
        n_folds=5,
        lgb_params=param,
        random_state=42
    )
    return mean_auc


study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=42)
)
study.optimize(objective, n_trials=200)

print("Best AUC:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2025-07-30 05:17:36,692] A new study created in memory with name: no-name-fcfad5f4-7c1d-4113-ab8a-b8cc004a2511
# [I 2025-07-30 05:17:40,061] Trial 0 finished with value: 0.7362616009036904 and parameters: {'max_depth': 9, 'num_leaves': 192, 'n_estimators': 380, 'learning_rate': 0.17999888677491394, 'subsample': 0.7312037280884873, 'colsample_bytree': 0.6467983561008608, 'reg_lambda': 0.5902552855603126}. Best is trial 0 with value: 0.7362616009036904.
# [I 2025-07-30 05:17:47,174] Trial 1 finished with value: 0.6727233710278003 and parameters: {'max_depth': 14, 'num_leaves': 128, 'n_estimators': 369, 'learning_rate': 0.0071547637944449315, 'subsample': 0.8939819704323989, 'colsample_bytree': 0.8497327922401265, 'reg_lambda': 2.1312677156759787}. Best is trial 0 with value: 0.7362616009036904.
# [I 2025-07-30 05:17:48,786] Trial 2 finished with value: 0.764451799102102 and parameters: {'max_depth': 7, 'num_leaves': 39, 'n_estimators': 187, 'learning_rate': 0.1579021730580391, 'subsample': 0.7863890037284231, 'colsample_bytree': 0.6873687420594126, 'reg_lambda': 6.122410418276571}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:17:50,417] Trial 3 finished with value: 0.7329029458523852 and parameters: {'max_depth': 6, 'num_leaves': 33, 'n_estimators': 215, 'learning_rate': 0.13736492528089375, 'subsample': 0.8570351922786027, 'colsample_bytree': 0.6599021346475079, 'reg_lambda': 5.1472020397519795}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:17:53,478] Trial 4 finished with value: 0.7284784917126698 and parameters: {'max_depth': 11, 'num_leaves': 28, 'n_estimators': 324, 'learning_rate': 0.05198671298250017, 'subsample': 0.7130103185970559, 'colsample_bytree': 0.884665661176, 'reg_lambda': 9.656664010414849}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:17:54,446] Trial 5 finished with value: 0.7235065711812976 and parameters: {'max_depth': 13, 'num_leaves': 75, 'n_estimators': 94, 'learning_rate': 0.2055856749271349, 'subsample': 0.7880304987479203, 'colsample_bytree': 0.6366114704534336, 'reg_lambda': 4.956817332011589}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:17:55,614] Trial 6 finished with value: 0.7330013788588061 and parameters: {'max_depth': 5, 'num_leaves': 31, 'n_estimators': 166, 'learning_rate': 0.1990941630218406, 'subsample': 0.7623422152178821, 'colsample_bytree': 0.7560204063533432, 'reg_lambda': 5.4716356906393635}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:01,216] Trial 7 finished with value: 0.7348021753501209 and parameters: {'max_depth': 7, 'num_leaves': 125, 'n_estimators': 399, 'learning_rate': 0.28191018352769254, 'subsample': 0.8789654700855298, 'colsample_bytree': 0.7793699936433256, 'reg_lambda': 9.219523607880937}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:01,698] Trial 8 finished with value: 0.72560222330887 and parameters: {'max_depth': 5, 'num_leaves': 22, 'n_estimators': 70, 'learning_rate': 0.09827376889821604, 'subsample': 0.7777354579378963, 'colsample_bytree': 0.6814047095321688, 'reg_lambda': 8.289087716427774}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:04,381] Trial 9 finished with value: 0.7205722997805988 and parameters: {'max_depth': 8, 'num_leaves': 70, 'n_estimators': 294, 'learning_rate': 0.04313634326745403, 'subsample': 0.8604393961508079, 'colsample_bytree': 0.6223651931039312, 'reg_lambda': 9.869000496639167}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:10,724] Trial 10 finished with value: 0.750264588596723 and parameters: {'max_depth': 10, 'num_leaves': 85, 'n_estimators': 487, 'learning_rate': 0.26462211310465267, 'subsample': 0.8280177004935113, 'colsample_bytree': 0.7117178038640947, 'reg_lambda': 7.1490861880403305}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:15,265] Trial 11 finished with value: 0.7322376129814542 and parameters: {'max_depth': 11, 'num_leaves': 80, 'n_estimators': 499, 'learning_rate': 0.29776688380676863, 'subsample': 0.8234908945986043, 'colsample_bytree': 0.7181615015598785, 'reg_lambda': 7.144705792565214}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:19,746] Trial 12 finished with value: 0.7422455222571668 and parameters: {'max_depth': 10, 'num_leaves': 102, 'n_estimators': 496, 'learning_rate': 0.24313397054099598, 'subsample': 0.816367424081938, 'colsample_bytree': 0.7152923682487957, 'reg_lambda': 6.7322393389379975}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:23,810] Trial 13 finished with value: 0.7349696382821695 and parameters: {'max_depth': 8, 'num_leaves': 60, 'n_estimators': 209, 'learning_rate': 0.12008453784367978, 'subsample': 0.8364332009562235, 'colsample_bytree': 0.7087287164835085, 'reg_lambda': 3.434564889780499}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:25,628] Trial 14 finished with value: 0.7203432729557834 and parameters: {'max_depth': 12, 'num_leaves': 148, 'n_estimators': 176, 'learning_rate': 0.2520190613502454, 'subsample': 0.7489376585289884, 'colsample_bytree': 0.7990219285835948, 'reg_lambda': 7.052111139795742}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:29,749] Trial 15 finished with value: 0.7442726831411776 and parameters: {'max_depth': 15, 'num_leaves': 56, 'n_estimators': 437, 'learning_rate': 0.16522157551021352, 'subsample': 0.7994839578245553, 'colsample_bytree': 0.6877616079514453, 'reg_lambda': 3.3492413349953627}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:32,007] Trial 16 finished with value: 0.7356143987006002 and parameters: {'max_depth': 9, 'num_leaves': 93, 'n_estimators': 253, 'learning_rate': 0.22770886148690905, 'subsample': 0.8468037635303126, 'colsample_bytree': 0.6017622875273795, 'reg_lambda': 6.313746114345026}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:35,278] Trial 17 finished with value: 0.733977024310245 and parameters: {'max_depth': 7, 'num_leaves': 45, 'n_estimators': 125, 'learning_rate': 0.0911696780550676, 'subsample': 0.8109092911739997, 'colsample_bytree': 0.8142096220620909, 'reg_lambda': 8.279594721980834}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:37,824] Trial 18 finished with value: 0.7262137118841415 and parameters: {'max_depth': 10, 'num_leaves': 164, 'n_estimators': 262, 'learning_rate': 0.2664445667800065, 'subsample': 0.7728253858247388, 'colsample_bytree': 0.7404337925292456, 'reg_lambda': 8.083568636191796}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:40,615] Trial 19 finished with value: 0.7366063349583853 and parameters: {'max_depth': 7, 'num_leaves': 44, 'n_estimators': 332, 'learning_rate': 0.21315418902410077, 'subsample': 0.7451086398830278, 'colsample_bytree': 0.7593416502378108, 'reg_lambda': 3.210193955226587}. Best is trial 2 with value: 0.764451799102102.
# [I 2025-07-30 05:18:44,673] Trial 20 finished with value: 0.7680447205928942 and parameters: {'max_depth': 12, 'num_leaves': 92, 'n_estimators': 444, 'learning_rate': 0.15165666052059232, 'subsample': 0.7870681559867984, 'colsample_bytree': 0.6749289217600603, 'reg_lambda': 4.104766053382841}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:18:50,833] Trial 21 finished with value: 0.7635886470828311 and parameters: {'max_depth': 12, 'num_leaves': 90, 'n_estimators': 453, 'learning_rate': 0.1600774086467208, 'subsample': 0.7964775135823392, 'colsample_bytree': 0.6778447752293706, 'reg_lambda': 4.078558670920948}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:18:54,808] Trial 22 finished with value: 0.7588805936249978 and parameters: {'max_depth': 13, 'num_leaves': 116, 'n_estimators': 427, 'learning_rate': 0.15646453490953438, 'subsample': 0.7907321071500575, 'colsample_bytree': 0.6701612409177755, 'reg_lambda': 4.300429881256754}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:01,274] Trial 23 finished with value: 0.7515808083003203 and parameters: {'max_depth': 12, 'num_leaves': 102, 'n_estimators': 456, 'learning_rate': 0.12374284947971895, 'subsample': 0.804567246531941, 'colsample_bytree': 0.6818230181542979, 'reg_lambda': 2.0810890812633334}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:04,124] Trial 24 finished with value: 0.7453775578143274 and parameters: {'max_depth': 12, 'num_leaves': 134, 'n_estimators': 332, 'learning_rate': 0.17983331165174002, 'subsample': 0.7622416816126588, 'colsample_bytree': 0.6110180685423716, 'reg_lambda': 4.2868101067191295}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:08,007] Trial 25 finished with value: 0.7431090521235516 and parameters: {'max_depth': 14, 'num_leaves': 61, 'n_estimators': 405, 'learning_rate': 0.09502369661413479, 'subsample': 0.7848912983501349, 'colsample_bytree': 0.6450442476024331, 'reg_lambda': 5.656345220457096}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:14,213] Trial 26 finished with value: 0.7316985916287129 and parameters: {'max_depth': 11, 'num_leaves': 93, 'n_estimators': 468, 'learning_rate': 0.14031867253645242, 'subsample': 0.7644271875285907, 'colsample_bytree': 0.6614254962069737, 'reg_lambda': 2.2936260006314626}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:15,974] Trial 27 finished with value: 0.7555891757693833 and parameters: {'max_depth': 13, 'num_leaves': 153, 'n_estimators': 155, 'learning_rate': 0.17663277611927086, 'subsample': 0.7985084805977629, 'colsample_bytree': 0.7383530267308537, 'reg_lambda': 4.115557788320471}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:18,477] Trial 28 finished with value: 0.7359429248289965 and parameters: {'max_depth': 15, 'num_leaves': 44, 'n_estimators': 222, 'learning_rate': 0.11209548392563903, 'subsample': 0.7382451499610457, 'colsample_bytree': 0.6951307098856492, 'reg_lambda': 0.9619296493177059}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:21,215] Trial 29 finished with value: 0.7287556052560679 and parameters: {'max_depth': 9, 'num_leaves': 186, 'n_estimators': 286, 'learning_rate': 0.06874085788451673, 'subsample': 0.7246841850239546, 'colsample_bytree': 0.6328866153784893, 'reg_lambda': 2.7396686268766786}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:26,860] Trial 30 finished with value: 0.7427073951488401 and parameters: {'max_depth': 11, 'num_leaves': 106, 'n_estimators': 354, 'learning_rate': 0.15308407356676668, 'subsample': 0.7729951726683293, 'colsample_bytree': 0.6561185862391334, 'reg_lambda': 0.22982332626149837}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:30,791] Trial 31 finished with value: 0.7558907945511478 and parameters: {'max_depth': 13, 'num_leaves': 115, 'n_estimators': 426, 'learning_rate': 0.1596660493260324, 'subsample': 0.7924530784457516, 'colsample_bytree': 0.6669544691110051, 'reg_lambda': 4.342718289001972}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:38,319] Trial 32 finished with value: 0.7455812870862927 and parameters: {'max_depth': 14, 'num_leaves': 137, 'n_estimators': 386, 'learning_rate': 0.18930607415446007, 'subsample': 0.8133291146469271, 'colsample_bytree': 0.6725403415374482, 'reg_lambda': 5.965250164233346}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:42,212] Trial 33 finished with value: 0.7536718152701262 and parameters: {'max_depth': 12, 'num_leaves': 110, 'n_estimators': 425, 'learning_rate': 0.14070720145733134, 'subsample': 0.753098670308742, 'colsample_bytree': 0.6981795065691175, 'reg_lambda': 4.675909159170094}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:46,675] Trial 34 finished with value: 0.7490481088873986 and parameters: {'max_depth': 14, 'num_leaves': 89, 'n_estimators': 453, 'learning_rate': 0.16917451669920577, 'subsample': 0.7859410899135525, 'colsample_bytree': 0.7326083064799986, 'reg_lambda': 3.7999360539088993}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:51,958] Trial 35 finished with value: 0.7451247310505295 and parameters: {'max_depth': 13, 'num_leaves': 72, 'n_estimators': 351, 'learning_rate': 0.13017552390005047, 'subsample': 0.7996486430045014, 'colsample_bytree': 0.6438058205227267, 'reg_lambda': 4.997584426006945}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:19:54,964] Trial 36 finished with value: 0.7438404040625319 and parameters: {'max_depth': 6, 'num_leaves': 49, 'n_estimators': 410, 'learning_rate': 0.1507923092075103, 'subsample': 0.781360225506437, 'colsample_bytree': 0.6259837502768367, 'reg_lambda': 1.1149051788306807}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:02,111] Trial 37 finished with value: 0.730638164011504 and parameters: {'max_depth': 13, 'num_leaves': 118, 'n_estimators': 468, 'learning_rate': 0.1938644218226951, 'subsample': 0.8291845796942223, 'colsample_bytree': 0.899485075849801, 'reg_lambda': 5.579626020523806}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:06,210] Trial 38 finished with value: 0.7413047229658575 and parameters: {'max_depth': 11, 'num_leaves': 125, 'n_estimators': 371, 'learning_rate': 0.07526513202106375, 'subsample': 0.7046775071934073, 'colsample_bytree': 0.843604537460608, 'reg_lambda': 2.65403343015866}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:09,041] Trial 39 finished with value: 0.7500678818458638 and parameters: {'max_depth': 12, 'num_leaves': 196, 'n_estimators': 308, 'learning_rate': 0.21339041535905992, 'subsample': 0.76131973258181, 'colsample_bytree': 0.655461278870941, 'reg_lambda': 4.879970691406683}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:10,414] Trial 40 finished with value: 0.7274724367896965 and parameters: {'max_depth': 14, 'num_leaves': 67, 'n_estimators': 103, 'learning_rate': 0.14318392085359002, 'subsample': 0.8879680868559862, 'colsample_bytree': 0.6776779905656449, 'reg_lambda': 1.673010668295817}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:16,439] Trial 41 finished with value: 0.7502330231042939 and parameters: {'max_depth': 13, 'num_leaves': 117, 'n_estimators': 431, 'learning_rate': 0.16107415546588416, 'subsample': 0.7957296474876155, 'colsample_bytree': 0.6670830255874912, 'reg_lambda': 4.394596192440697}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:20,583] Trial 42 finished with value: 0.6988993809542675 and parameters: {'max_depth': 13, 'num_leaves': 116, 'n_estimators': 383, 'learning_rate': 0.009335431105382874, 'subsample': 0.7919205809471828, 'colsample_bytree': 0.7034974209322712, 'reg_lambda': 3.7366150627546273}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:26,532] Trial 43 finished with value: 0.7530321300920122 and parameters: {'max_depth': 12, 'num_leaves': 80, 'n_estimators': 419, 'learning_rate': 0.11009611406229997, 'subsample': 0.773265528821793, 'colsample_bytree': 0.6697399899938902, 'reg_lambda': 5.342103004394037}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:30,636] Trial 44 finished with value: 0.743828775627393 and parameters: {'max_depth': 9, 'num_leaves': 99, 'n_estimators': 448, 'learning_rate': 0.18588462137923678, 'subsample': 0.8059352422952285, 'colsample_bytree': 0.690140905287066, 'reg_lambda': 4.609866477197181}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:31,157] Trial 45 finished with value: 0.737657118853181 and parameters: {'max_depth': 6, 'num_leaves': 38, 'n_estimators': 50, 'learning_rate': 0.1569280592231832, 'subsample': 0.8171585334975523, 'colsample_bytree': 0.7200098007559415, 'reg_lambda': 6.0824794736989265}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:34,792] Trial 46 finished with value: 0.7476876567892321 and parameters: {'max_depth': 11, 'num_leaves': 23, 'n_estimators': 466, 'learning_rate': 0.1698799680774855, 'subsample': 0.7915726673058285, 'colsample_bytree': 0.6508517560796235, 'reg_lambda': 3.9350119041412563}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:39,172] Trial 47 finished with value: 0.7335230022982093 and parameters: {'max_depth': 15, 'num_leaves': 142, 'n_estimators': 234, 'learning_rate': 0.20409603845345375, 'subsample': 0.7807389408952613, 'colsample_bytree': 0.6167344827745616, 'reg_lambda': 2.9782876692030817}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:43,911] Trial 48 finished with value: 0.7430684254496389 and parameters: {'max_depth': 8, 'num_leaves': 130, 'n_estimators': 489, 'learning_rate': 0.1304872995781915, 'subsample': 0.8380721591002197, 'colsample_bytree': 0.7602993813030207, 'reg_lambda': 7.665993246300298}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:45,681] Trial 49 finished with value: 0.7241123901103113 and parameters: {'max_depth': 10, 'num_leaves': 82, 'n_estimators': 181, 'learning_rate': 0.22482969333089187, 'subsample': 0.8219957994375999, 'colsample_bytree': 0.6364521795534507, 'reg_lambda': 6.603132866356619}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:50,578] Trial 50 finished with value: 0.7406362540323174 and parameters: {'max_depth': 5, 'num_leaves': 27, 'n_estimators': 439, 'learning_rate': 0.10956502162173158, 'subsample': 0.8064508048928501, 'colsample_bytree': 0.716156857592351, 'reg_lambda': 5.260646424129485}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:52,224] Trial 51 finished with value: 0.7322158344329469 and parameters: {'max_depth': 13, 'num_leaves': 157, 'n_estimators': 150, 'learning_rate': 0.17917389914778986, 'subsample': 0.793176143986707, 'colsample_bytree': 0.7264473417170275, 'reg_lambda': 4.091512332915186}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:54,409] Trial 52 finished with value: 0.7543710309697034 and parameters: {'max_depth': 14, 'num_leaves': 184, 'n_estimators': 196, 'learning_rate': 0.17409287095307052, 'subsample': 0.7682163046163843, 'colsample_bytree': 0.7419168503020237, 'reg_lambda': 3.5490404882378583}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:56,122] Trial 53 finished with value: 0.7514980513192402 and parameters: {'max_depth': 13, 'num_leaves': 171, 'n_estimators': 152, 'learning_rate': 0.15898320389362824, 'subsample': 0.8000581918117268, 'colsample_bytree': 0.6825690004558908, 'reg_lambda': 4.237338843750173}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:57,753] Trial 54 finished with value: 0.7405519227625713 and parameters: {'max_depth': 12, 'num_leaves': 152, 'n_estimators': 142, 'learning_rate': 0.14552161594228177, 'subsample': 0.755116029107673, 'colsample_bytree': 0.7770404225701989, 'reg_lambda': 4.6073728408509}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:20:59,132] Trial 55 finished with value: 0.7317027152617573 and parameters: {'max_depth': 14, 'num_leaves': 97, 'n_estimators': 123, 'learning_rate': 0.19797234710654912, 'subsample': 0.7788507175434882, 'colsample_bytree': 0.7028464427761246, 'reg_lambda': 3.0401561784546045}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:04,859] Trial 56 finished with value: 0.7584386887122581 and parameters: {'max_depth': 13, 'num_leaves': 124, 'n_estimators': 391, 'learning_rate': 0.13475122724242028, 'subsample': 0.8098940768116892, 'colsample_bytree': 0.6645776702462494, 'reg_lambda': 5.80722184743024}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:09,429] Trial 57 finished with value: 0.7413934517486883 and parameters: {'max_depth': 12, 'num_leaves': 110, 'n_estimators': 480, 'learning_rate': 0.117106809274439, 'subsample': 0.7867317803410294, 'colsample_bytree': 0.6633717287008875, 'reg_lambda': 5.834801831981077}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:15,648] Trial 58 finished with value: 0.7353929065648387 and parameters: {'max_depth': 11, 'num_leaves': 125, 'n_estimators': 398, 'learning_rate': 0.1319415812012281, 'subsample': 0.8671806075895316, 'colsample_bytree': 0.6431262988549205, 'reg_lambda': 6.3722330608747875}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:19,668] Trial 59 finished with value: 0.7491944882019265 and parameters: {'max_depth': 13, 'num_leaves': 140, 'n_estimators': 395, 'learning_rate': 0.08644093202266188, 'subsample': 0.8087331458499621, 'colsample_bytree': 0.6845548622756625, 'reg_lambda': 4.976731979179512}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:23,186] Trial 60 finished with value: 0.7426545731654774 and parameters: {'max_depth': 10, 'num_leaves': 119, 'n_estimators': 361, 'learning_rate': 0.1014319318080537, 'subsample': 0.8340057111908317, 'colsample_bytree': 0.6751202174709344, 'reg_lambda': 8.961940639747201}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:29,301] Trial 61 finished with value: 0.7345206390527937 and parameters: {'max_depth': 13, 'num_leaves': 105, 'n_estimators': 418, 'learning_rate': 0.16833721454418718, 'subsample': 0.8188068856992071, 'colsample_bytree': 0.6934620007412419, 'reg_lambda': 3.563330267401868}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:33,357] Trial 62 finished with value: 0.7522160766822013 and parameters: {'max_depth': 12, 'num_leaves': 168, 'n_estimators': 436, 'learning_rate': 0.15303021113136758, 'subsample': 0.7981176854872695, 'colsample_bytree': 0.6613545698239282, 'reg_lambda': 4.0004043715200925}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:39,835] Trial 63 finished with value: 0.745057655096641 and parameters: {'max_depth': 14, 'num_leaves': 146, 'n_estimators': 475, 'learning_rate': 0.18226225706687668, 'subsample': 0.8119276582159254, 'colsample_bytree': 0.7074727309891743, 'reg_lambda': 6.86619268140977}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:43,971] Trial 64 finished with value: 0.754978869740524 and parameters: {'max_depth': 13, 'num_leaves': 110, 'n_estimators': 448, 'learning_rate': 0.12526143841659076, 'subsample': 0.7882913365716424, 'colsample_bytree': 0.6499591172408585, 'reg_lambda': 5.2850417637165075}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:46,863] Trial 65 finished with value: 0.7487232592333628 and parameters: {'max_depth': 12, 'num_leaves': 91, 'n_estimators': 267, 'learning_rate': 0.13711927774393956, 'subsample': 0.7758362873930968, 'colsample_bytree': 0.7992601713641104, 'reg_lambda': 4.444645017148946}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:49,254] Trial 66 finished with value: 0.7335682239804614 and parameters: {'max_depth': 14, 'num_leaves': 131, 'n_estimators': 242, 'learning_rate': 0.16464725681544248, 'subsample': 0.8027737428394539, 'colsample_bytree': 0.6316364830432082, 'reg_lambda': 5.62265677649194}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:55,867] Trial 67 finished with value: 0.7379890883193527 and parameters: {'max_depth': 15, 'num_leaves': 86, 'n_estimators': 499, 'learning_rate': 0.14598264567938904, 'subsample': 0.8251657970768146, 'colsample_bytree': 0.6736132944641456, 'reg_lambda': 4.8382825780726595}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:57,628] Trial 68 finished with value: 0.7545576190833956 and parameters: {'max_depth': 13, 'num_leaves': 74, 'n_estimators': 195, 'learning_rate': 0.17669596489192904, 'subsample': 0.7689705374943577, 'colsample_bytree': 0.6079202592785024, 'reg_lambda': 7.517785267030451}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:21:58,780] Trial 69 finished with value: 0.724633239418645 and parameters: {'max_depth': 11, 'num_leaves': 65, 'n_estimators': 91, 'learning_rate': 0.19338472151324562, 'subsample': 0.8475959942108805, 'colsample_bytree': 0.6908507576362626, 'reg_lambda': 3.290343272146283}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:04,915] Trial 70 finished with value: 0.7552486080065799 and parameters: {'max_depth': 12, 'num_leaves': 52, 'n_estimators': 457, 'learning_rate': 0.2145692015834114, 'subsample': 0.7835107371728778, 'colsample_bytree': 0.7267576444342517, 'reg_lambda': 6.215118962939961}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:09,188] Trial 71 finished with value: 0.7458837754704606 and parameters: {'max_depth': 12, 'num_leaves': 52, 'n_estimators': 457, 'learning_rate': 0.2112930423017978, 'subsample': 0.7843064642809887, 'colsample_bytree': 0.7407575632072325, 'reg_lambda': 6.362419304412489}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:13,121] Trial 72 finished with value: 0.758667730664073 and parameters: {'max_depth': 13, 'num_leaves': 56, 'n_estimators': 410, 'learning_rate': 0.2274961185551576, 'subsample': 0.7953927599423037, 'colsample_bytree': 0.749318313529469, 'reg_lambda': 6.210424878336489}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:18,824] Trial 73 finished with value: 0.7404226283906896 and parameters: {'max_depth': 13, 'num_leaves': 37, 'n_estimators': 413, 'learning_rate': 0.25188761387229663, 'subsample': 0.7950621377338807, 'colsample_bytree': 0.7490457022156389, 'reg_lambda': 5.869421995933055}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:22,232] Trial 74 finished with value: 0.7211166674952113 and parameters: {'max_depth': 13, 'num_leaves': 122, 'n_estimators': 338, 'learning_rate': 0.27754236741143945, 'subsample': 0.8011266820923618, 'colsample_bytree': 0.7911158037078244, 'reg_lambda': 4.173820852939057}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:25,704] Trial 75 finished with value: 0.7632753619058184 and parameters: {'max_depth': 14, 'num_leaves': 77, 'n_estimators': 388, 'learning_rate': 0.2377602259155732, 'subsample': 0.8130343292293124, 'colsample_bytree': 0.6580506875173033, 'reg_lambda': 5.111538054868212}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:31,448] Trial 76 finished with value: 0.7502132177784004 and parameters: {'max_depth': 14, 'num_leaves': 79, 'n_estimators': 377, 'learning_rate': 0.29601287865540904, 'subsample': 0.8124356126532647, 'colsample_bytree': 0.8440050754756713, 'reg_lambda': 5.528811147812941}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:35,393] Trial 77 finished with value: 0.7413706781717595 and parameters: {'max_depth': 14, 'num_leaves': 58, 'n_estimators': 396, 'learning_rate': 0.2502252885149045, 'subsample': 0.79023831193853, 'colsample_bytree': 0.8259663112091655, 'reg_lambda': 5.117626855877237}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:40,233] Trial 78 finished with value: 0.7416864386963686 and parameters: {'max_depth': 15, 'num_leaves': 98, 'n_estimators': 305, 'learning_rate': 0.2373713080285202, 'subsample': 0.8054484722727574, 'colsample_bytree': 0.6665597441240932, 'reg_lambda': 6.57347856776727}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:43,893] Trial 79 finished with value: 0.7357001432615347 and parameters: {'max_depth': 8, 'num_leaves': 114, 'n_estimators': 407, 'learning_rate': 0.13724726569868814, 'subsample': 0.8164689979221209, 'colsample_bytree': 0.6569805010589551, 'reg_lambda': 4.62671784705091}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:47,489] Trial 80 finished with value: 0.7454942880210506 and parameters: {'max_depth': 14, 'num_leaves': 63, 'n_estimators': 427, 'learning_rate': 0.22820419744945378, 'subsample': 0.7788179543474971, 'colsample_bytree': 0.6481971214553801, 'reg_lambda': 7.204096641593578}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:53,632] Trial 81 finished with value: 0.7487170563110126 and parameters: {'max_depth': 13, 'num_leaves': 87, 'n_estimators': 440, 'learning_rate': 0.26296372376515154, 'subsample': 0.7974850816100671, 'colsample_bytree': 0.7767518007248604, 'reg_lambda': 3.8306237353964976}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:22:57,580] Trial 82 finished with value: 0.746727446877094 and parameters: {'max_depth': 13, 'num_leaves': 94, 'n_estimators': 390, 'learning_rate': 0.14993188038042013, 'subsample': 0.7912620339788651, 'colsample_bytree': 0.7669853423514414, 'reg_lambda': 4.3157282606512695}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:01,107] Trial 83 finished with value: 0.749342249993279 and parameters: {'max_depth': 14, 'num_leaves': 77, 'n_estimators': 373, 'learning_rate': 0.16078497235504757, 'subsample': 0.8075629578678876, 'colsample_bytree': 0.6798641693044772, 'reg_lambda': 5.136682442334832}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:06,850] Trial 84 finished with value: 0.7576253178500201 and parameters: {'max_depth': 12, 'num_leaves': 103, 'n_estimators': 424, 'learning_rate': 0.2391994900680077, 'subsample': 0.7954225798179407, 'colsample_bytree': 0.6996959089462402, 'reg_lambda': 5.7677159270886635}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:10,773] Trial 85 finished with value: 0.7482434825661823 and parameters: {'max_depth': 12, 'num_leaves': 104, 'n_estimators': 421, 'learning_rate': 0.23767748664286487, 'subsample': 0.8213726943580995, 'colsample_bytree': 0.6995226958203654, 'reg_lambda': 5.852364362769523}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:14,305] Trial 86 finished with value: 0.75262779081897 and parameters: {'max_depth': 12, 'num_leaves': 108, 'n_estimators': 407, 'learning_rate': 0.2224397309339261, 'subsample': 0.7670907743231019, 'colsample_bytree': 0.6853450715148357, 'reg_lambda': 6.089690756362925}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:19,818] Trial 87 finished with value: 0.7427863351886838 and parameters: {'max_depth': 11, 'num_leaves': 114, 'n_estimators': 345, 'learning_rate': 0.04358021016993885, 'subsample': 0.7945293662327929, 'colsample_bytree': 0.6701130955385308, 'reg_lambda': 5.482760369491644}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:23,031] Trial 88 finished with value: 0.7291033685186481 and parameters: {'max_depth': 11, 'num_leaves': 69, 'n_estimators': 359, 'learning_rate': 0.2671406210581697, 'subsample': 0.8309830547195426, 'colsample_bytree': 0.6407609458762351, 'reg_lambda': 4.832210539529493}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:25,499] Trial 89 finished with value: 0.7486243552476023 and parameters: {'max_depth': 5, 'num_leaves': 29, 'n_estimators': 429, 'learning_rate': 0.23692058974121305, 'subsample': 0.7589832627929327, 'colsample_bytree': 0.6240050460871059, 'reg_lambda': 6.911317245782878}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:31,210] Trial 90 finished with value: 0.7395014855290957 and parameters: {'max_depth': 7, 'num_leaves': 101, 'n_estimators': 466, 'learning_rate': 0.2030328979976327, 'subsample': 0.7755188023008379, 'colsample_bytree': 0.7104383953075728, 'reg_lambda': 6.503834819487242}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:36,849] Trial 91 finished with value: 0.756576503799421 and parameters: {'max_depth': 13, 'num_leaves': 40, 'n_estimators': 385, 'learning_rate': 0.15531553329553072, 'subsample': 0.802052169661271, 'colsample_bytree': 0.6550179496357672, 'reg_lambda': 3.6790752754441294}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:42,849] Trial 92 finished with value: 0.7354967540542208 and parameters: {'max_depth': 13, 'num_leaves': 35, 'n_estimators': 443, 'learning_rate': 0.1234009279026956, 'subsample': 0.8027480470574415, 'colsample_bytree': 0.6576269039846883, 'reg_lambda': 3.6025424357777966}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:46,364] Trial 93 finished with value: 0.7480885787476298 and parameters: {'max_depth': 13, 'num_leaves': 40, 'n_estimators': 389, 'learning_rate': 0.18776346102918196, 'subsample': 0.7876293849944747, 'colsample_bytree': 0.6780159507596303, 'reg_lambda': 2.6240082592632934}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:49,778] Trial 94 finished with value: 0.7516897490725001 and parameters: {'max_depth': 12, 'num_leaves': 45, 'n_estimators': 365, 'learning_rate': 0.15515085687898017, 'subsample': 0.8126808347111617, 'colsample_bytree': 0.6657425239652764, 'reg_lambda': 5.764539340997245}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:55,333] Trial 95 finished with value: 0.7573779280460531 and parameters: {'max_depth': 13, 'num_leaves': 126, 'n_estimators': 403, 'learning_rate': 0.17090065452701825, 'subsample': 0.7838184703977331, 'colsample_bytree': 0.6520478089613365, 'reg_lambda': 4.511787226529062}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:23:57,686] Trial 96 finished with value: 0.7386499557069097 and parameters: {'max_depth': 12, 'num_leaves': 20, 'n_estimators': 320, 'learning_rate': 0.17100546396571137, 'subsample': 0.7843601284017178, 'colsample_bytree': 0.6317377629366207, 'reg_lambda': 3.0949618997158588}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:01,166] Trial 97 finished with value: 0.7651722891843507 and parameters: {'max_depth': 14, 'num_leaves': 127, 'n_estimators': 380, 'learning_rate': 0.1449942724255779, 'subsample': 0.7809888533338122, 'colsample_bytree': 0.6512678486399676, 'reg_lambda': 5.363058645593997}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:06,828] Trial 98 finished with value: 0.7514977279867733 and parameters: {'max_depth': 15, 'num_leaves': 134, 'n_estimators': 403, 'learning_rate': 0.13304553249879503, 'subsample': 0.7821966192290943, 'colsample_bytree': 0.6385896299823176, 'reg_lambda': 5.3212727040629515}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:11,302] Trial 99 finished with value: 0.7489550347792158 and parameters: {'max_depth': 14, 'num_leaves': 133, 'n_estimators': 486, 'learning_rate': 0.145964666471525, 'subsample': 0.771404729485217, 'colsample_bytree': 0.6952135640087247, 'reg_lambda': 4.495380808940957}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:14,538] Trial 100 finished with value: 0.7624654216435416 and parameters: {'max_depth': 9, 'num_leaves': 126, 'n_estimators': 373, 'learning_rate': 0.2445182772186183, 'subsample': 0.7787631637059984, 'colsample_bytree': 0.6725200283430699, 'reg_lambda': 4.800530862589077}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:19,989] Trial 101 finished with value: 0.7483376948164987 and parameters: {'max_depth': 9, 'num_leaves': 122, 'n_estimators': 415, 'learning_rate': 0.24497014875831005, 'subsample': 0.7896138319652718, 'colsample_bytree': 0.6496386087756654, 'reg_lambda': 4.772010554585195}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:22,947] Trial 102 finished with value: 0.7402231709567489 and parameters: {'max_depth': 7, 'num_leaves': 120, 'n_estimators': 373, 'learning_rate': 0.2628976195364552, 'subsample': 0.776548609089014, 'colsample_bytree': 0.6735008669967325, 'reg_lambda': 6.041926454106612}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:26,592] Trial 103 finished with value: 0.7400154335073704 and parameters: {'max_depth': 8, 'num_leaves': 127, 'n_estimators': 430, 'learning_rate': 0.23151232999145643, 'subsample': 0.7953293263502434, 'colsample_bytree': 0.6873310656568378, 'reg_lambda': 5.114276270818643}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:31,624] Trial 104 finished with value: 0.7381671480677964 and parameters: {'max_depth': 8, 'num_leaves': 83, 'n_estimators': 381, 'learning_rate': 0.220246876005596, 'subsample': 0.7651088422780126, 'colsample_bytree': 0.6598215456804497, 'reg_lambda': 5.389618531527702}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:34,697] Trial 105 finished with value: 0.7531024977260412 and parameters: {'max_depth': 6, 'num_leaves': 60, 'n_estimators': 399, 'learning_rate': 0.13921838938546258, 'subsample': 0.8089194413551436, 'colsample_bytree': 0.6819720807454249, 'reg_lambda': 4.047063738581167}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:37,880] Trial 106 finished with value: 0.7597201161312095 and parameters: {'max_depth': 14, 'num_leaves': 138, 'n_estimators': 352, 'learning_rate': 0.24480445545649154, 'subsample': 0.7798121768376368, 'colsample_bytree': 0.6637544093797392, 'reg_lambda': 5.670127259157098}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:42,899] Trial 107 finished with value: 0.7676733433185514 and parameters: {'max_depth': 14, 'num_leaves': 137, 'n_estimators': 351, 'learning_rate': 0.2594519259855985, 'subsample': 0.7785480764918962, 'colsample_bytree': 0.6703166798117891, 'reg_lambda': 5.666888243228485}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:45,986] Trial 108 finished with value: 0.757601264270622 and parameters: {'max_depth': 15, 'num_leaves': 130, 'n_estimators': 348, 'learning_rate': 0.2476217560583033, 'subsample': 0.7793399262495817, 'colsample_bytree': 0.6693614827781268, 'reg_lambda': 5.621790141856813}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:48,869] Trial 109 finished with value: 0.7439873927343524 and parameters: {'max_depth': 14, 'num_leaves': 139, 'n_estimators': 325, 'learning_rate': 0.2565609081200816, 'subsample': 0.7723702120026842, 'colsample_bytree': 0.6626623220673786, 'reg_lambda': 6.202803182479872}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:51,762] Trial 110 finished with value: 0.7390595218887237 and parameters: {'max_depth': 14, 'num_leaves': 148, 'n_estimators': 340, 'learning_rate': 0.2586928402895197, 'subsample': 0.7583786881846671, 'colsample_bytree': 0.6446826551010487, 'reg_lambda': 5.012277328701174}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:24:56,829] Trial 111 finished with value: 0.7544724714520789 and parameters: {'max_depth': 14, 'num_leaves': 136, 'n_estimators': 353, 'learning_rate': 0.2716084732375181, 'subsample': 0.789672377076281, 'colsample_bytree': 0.6781039978257392, 'reg_lambda': 6.024758719571637}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:00,190] Trial 112 finished with value: 0.750922980466489 and parameters: {'max_depth': 14, 'num_leaves': 143, 'n_estimators': 366, 'learning_rate': 0.24218025142841879, 'subsample': 0.7980065150929931, 'colsample_bytree': 0.6892706728400811, 'reg_lambda': 5.724822034107282}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:03,447] Trial 113 finished with value: 0.7417098138188785 and parameters: {'max_depth': 9, 'num_leaves': 90, 'n_estimators': 379, 'learning_rate': 0.2840146188509884, 'subsample': 0.7868196568676796, 'colsample_bytree': 0.7012349061404659, 'reg_lambda': 6.686294797120993}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:09,208] Trial 114 finished with value: 0.7272001325959957 and parameters: {'max_depth': 15, 'num_leaves': 114, 'n_estimators': 451, 'learning_rate': 0.2567824487627277, 'subsample': 0.747854859912728, 'colsample_bytree': 0.67335069132358, 'reg_lambda': 5.45751973978888}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:12,995] Trial 115 finished with value: 0.7490133118887438 and parameters: {'max_depth': 10, 'num_leaves': 93, 'n_estimators': 415, 'learning_rate': 0.11740062752822036, 'subsample': 0.7792562097714538, 'colsample_bytree': 0.6636073955915762, 'reg_lambda': 6.373067746455745}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:16,383] Trial 116 finished with value: 0.7513376685186456 and parameters: {'max_depth': 14, 'num_leaves': 143, 'n_estimators': 391, 'learning_rate': 0.27218168239020246, 'subsample': 0.770578649254839, 'colsample_bytree': 0.681772365734445, 'reg_lambda': 5.246634334162479}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:22,507] Trial 117 finished with value: 0.7524653971886357 and parameters: {'max_depth': 14, 'num_leaves': 124, 'n_estimators': 460, 'learning_rate': 0.21801897261427153, 'subsample': 0.7940558417383647, 'colsample_bytree': 0.6941417428031412, 'reg_lambda': 4.962583045522836}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:25,333] Trial 118 finished with value: 0.7572431449570977 and parameters: {'max_depth': 13, 'num_leaves': 106, 'n_estimators': 312, 'learning_rate': 0.22959066113129556, 'subsample': 0.7738027309571573, 'colsample_bytree': 0.6685326701364436, 'reg_lambda': 5.8885751269021025}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:31,335] Trial 119 finished with value: 0.7502896127066399 and parameters: {'max_depth': 15, 'num_leaves': 111, 'n_estimators': 436, 'learning_rate': 0.24101269195505215, 'subsample': 0.7992260444509076, 'colsample_bytree': 0.7207506975194755, 'reg_lambda': 5.5933746000668165}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:34,433] Trial 120 finished with value: 0.7202371273593611 and parameters: {'max_depth': 14, 'num_leaves': 157, 'n_estimators': 284, 'learning_rate': 0.23351789579356763, 'subsample': 0.7817789412291613, 'colsample_bytree': 0.8625864374629207, 'reg_lambda': 4.278441796477961}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:37,567] Trial 121 finished with value: 0.7602397328597589 and parameters: {'max_depth': 15, 'num_leaves': 130, 'n_estimators': 352, 'learning_rate': 0.24791574036007183, 'subsample': 0.7783161861339193, 'colsample_bytree': 0.6717145143728316, 'reg_lambda': 5.722812716248262}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:40,628] Trial 122 finished with value: 0.7666312067926188 and parameters: {'max_depth': 15, 'num_leaves': 136, 'n_estimators': 358, 'learning_rate': 0.2512112751349363, 'subsample': 0.7630998338138263, 'colsample_bytree': 0.6551003096569918, 'reg_lambda': 4.787891758321605}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:45,660] Trial 123 finished with value: 0.7568786996249408 and parameters: {'max_depth': 15, 'num_leaves': 130, 'n_estimators': 360, 'learning_rate': 0.2526763097694299, 'subsample': 0.7652395048078799, 'colsample_bytree': 0.6545353834186799, 'reg_lambda': 4.6857431419586115}. Best is trial 20 with value: 0.7680447205928942.
# [I 2025-07-30 05:25:48,459] Trial 124 finished with value: 0.7759674107629702 and parameters: {'max_depth': 15, 'num_leaves': 138, 'n_estimators': 332, 'learning_rate': 0.281393510469453, 'subsample': 0.7545781389603842, 'colsample_bytree': 0.6602598373388076, 'reg_lambda': 3.870660430860955}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:25:51,246] Trial 125 finished with value: 0.73271059426228 and parameters: {'max_depth': 15, 'num_leaves': 138, 'n_estimators': 330, 'learning_rate': 0.28167737698696504, 'subsample': 0.7395920843440459, 'colsample_bytree': 0.6602875042123136, 'reg_lambda': 3.933839210493938}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:25:56,077] Trial 126 finished with value: 0.7549185589807628 and parameters: {'max_depth': 15, 'num_leaves': 136, 'n_estimators': 355, 'learning_rate': 0.2495169328727486, 'subsample': 0.7535560622873394, 'colsample_bytree': 0.6351958952618778, 'reg_lambda': 4.815268983564865}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:25:58,855] Trial 127 finished with value: 0.7345289188846866 and parameters: {'max_depth': 15, 'num_leaves': 133, 'n_estimators': 335, 'learning_rate': 0.26952563059986867, 'subsample': 0.7250694843325193, 'colsample_bytree': 0.6447613072133447, 'reg_lambda': 4.398204668833673}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:01,653] Trial 128 finished with value: 0.7527838244652545 and parameters: {'max_depth': 15, 'num_leaves': 153, 'n_estimators': 317, 'learning_rate': 0.2939271957578485, 'subsample': 0.7593201086415099, 'colsample_bytree': 0.6767508987876224, 'reg_lambda': 3.3982419054572386}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:04,656] Trial 129 finished with value: 0.7609646434985817 and parameters: {'max_depth': 15, 'num_leaves': 146, 'n_estimators': 348, 'learning_rate': 0.27774233171411844, 'subsample': 0.7689388052709355, 'colsample_bytree': 0.6517856279039648, 'reg_lambda': 4.148167434730723}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:09,161] Trial 130 finished with value: 0.7493114507433905 and parameters: {'max_depth': 15, 'num_leaves': 147, 'n_estimators': 299, 'learning_rate': 0.2911824884436634, 'subsample': 0.7514010925944968, 'colsample_bytree': 0.6508694580436868, 'reg_lambda': 3.8553234785847956}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:12,053] Trial 131 finished with value: 0.7348102152850536 and parameters: {'max_depth': 15, 'num_leaves': 128, 'n_estimators': 342, 'learning_rate': 0.26145528351127545, 'subsample': 0.7640096316211633, 'colsample_bytree': 0.616333962545276, 'reg_lambda': 4.101229317998509}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:15,166] Trial 132 finished with value: 0.7434810592256522 and parameters: {'max_depth': 15, 'num_leaves': 140, 'n_estimators': 369, 'learning_rate': 0.25533264403282446, 'subsample': 0.7432362052421359, 'colsample_bytree': 0.6575523197240934, 'reg_lambda': 4.58872778916773}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:20,198] Trial 133 finished with value: 0.7541474425354584 and parameters: {'max_depth': 14, 'num_leaves': 143, 'n_estimators': 353, 'learning_rate': 0.27746190188111425, 'subsample': 0.7699652805896722, 'colsample_bytree': 0.6713193182170983, 'reg_lambda': 5.136662613940404}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:23,075] Trial 134 finished with value: 0.7501153272658904 and parameters: {'max_depth': 15, 'num_leaves': 120, 'n_estimators': 328, 'learning_rate': 0.28694330257238737, 'subsample': 0.7777209139531136, 'colsample_bytree': 0.6652746861040281, 'reg_lambda': 4.2420700082721225}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:26,225] Trial 135 finished with value: 0.7288942405545908 and parameters: {'max_depth': 14, 'num_leaves': 150, 'n_estimators': 367, 'learning_rate': 0.2436877210388421, 'subsample': 0.7739100420280982, 'colsample_bytree': 0.6263869073030683, 'reg_lambda': 3.765153652970372}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:29,204] Trial 136 finished with value: 0.747018000179968 and parameters: {'max_depth': 15, 'num_leaves': 71, 'n_estimators': 344, 'learning_rate': 0.2764356437104387, 'subsample': 0.7861450764884144, 'colsample_bytree': 0.6448390839575412, 'reg_lambda': 4.764682499108413}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:34,527] Trial 137 finished with value: 0.7409598477226014 and parameters: {'max_depth': 14, 'num_leaves': 160, 'n_estimators': 376, 'learning_rate': 0.16526223423688563, 'subsample': 0.7674536221511382, 'colsample_bytree': 0.654250896979598, 'reg_lambda': 4.980071099954888}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:26:37,679] Trial 138 finished with value: 0.7496668856643016 and parameters: {'max_depth': 14, 'num_leaves': 134, 'n_estimators': 356, 'learning_rate': 0.26910191212324525, 'subsample': 0.7821765518901758, 'colsample_bytree': 0.6840867915289659, 'reg_lambda': 5.339239375411975}. Best is trial 124 with value: 0.7759674107629702.
# ...
# [I 2025-07-30 05:27:43,702] Trial 155 finished with value: 0.7485185113705152 and parameters: {'max_depth': 6, 'num_leaves': 63, 'n_estimators': 391, 'learning_rate': 0.16283481269770433, 'subsample': 0.818369222447755, 'colsample_bytree': 0.6776786487020895, 'reg_lambda': 5.746535460025276}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:27:48,551] Trial 156 finished with value: 0.7554627581714687 and parameters: {'max_depth': 7, 'num_leaves': 123, 'n_estimators': 348, 'learning_rate': 0.13405583270949153, 'subsample': 0.7853038765461958, 'colsample_bytree': 0.6614591600347848, 'reg_lambda': 5.474851112439281}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:27:52,419] Trial 157 finished with value: 0.7517156778536419 and parameters: {'max_depth': 15, 'num_leaves': 48, 'n_estimators': 403, 'learning_rate': 0.1502698527226221, 'subsample': 0.8272286540062952, 'colsample_bytree': 0.668956278307893, 'reg_lambda': 4.971162814018943}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:27:55,926] Trial 158 finished with value: 0.7483873032837495 and parameters: {'max_depth': 11, 'num_leaves': 112, 'n_estimators': 361, 'learning_rate': 0.10557747147018964, 'subsample': 0.8027269497838444, 'colsample_bytree': 0.6484565873365501, 'reg_lambda': 4.606277971064586}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:01,195] Trial 159 finished with value: 0.7449915598389409 and parameters: {'max_depth': 14, 'num_leaves': 117, 'n_estimators': 339, 'learning_rate': 0.14314947774083622, 'subsample': 0.7806723641723677, 'colsample_bytree': 0.6577412532562401, 'reg_lambda': 4.7956055178805785}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:04,693] Trial 160 finished with value: 0.7507873413510706 and parameters: {'max_depth': 13, 'num_leaves': 135, 'n_estimators': 385, 'learning_rate': 0.24219615068224443, 'subsample': 0.7980132739067061, 'colsample_bytree': 0.6832487860413743, 'reg_lambda': 4.396835549568707}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:08,495] Trial 161 finished with value: 0.7414621078866162 and parameters: {'max_depth': 12, 'num_leaves': 87, 'n_estimators': 412, 'learning_rate': 0.2396945740053523, 'subsample': 0.7943116147901829, 'colsample_bytree': 0.6912966691289749, 'reg_lambda': 5.813716433558526}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:14,283] Trial 162 finished with value: 0.7469135114944988 and parameters: {'max_depth': 12, 'num_leaves': 96, 'n_estimators': 426, 'learning_rate': 0.23242976136231913, 'subsample': 0.793528825246581, 'colsample_bytree': 0.7068372688408046, 'reg_lambda': 5.938319993321286}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:18,060] Trial 163 finished with value: 0.7494490752031865 and parameters: {'max_depth': 15, 'num_leaves': 130, 'n_estimators': 396, 'learning_rate': 0.2495830275498492, 'subsample': 0.786685738688424, 'colsample_bytree': 0.7487884642941858, 'reg_lambda': 6.145391324734701}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:23,740] Trial 164 finished with value: 0.7516787255760466 and parameters: {'max_depth': 12, 'num_leaves': 101, 'n_estimators': 475, 'learning_rate': 0.287916725325068, 'subsample': 0.7735317159996861, 'colsample_bytree': 0.6733358798086891, 'reg_lambda': 6.811302189776964}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:27,544] Trial 165 finished with value: 0.7320017382345874 and parameters: {'max_depth': 11, 'num_leaves': 82, 'n_estimators': 438, 'learning_rate': 0.24705981026856177, 'subsample': 0.7974318559851082, 'colsample_bytree': 0.6661991779584586, 'reg_lambda': 5.538111457690511}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:30,979] Trial 166 finished with value: 0.7443271304319343 and parameters: {'max_depth': 13, 'num_leaves': 139, 'n_estimators': 372, 'learning_rate': 0.2746181094290594, 'subsample': 0.8096585176699851, 'colsample_bytree': 0.6972611184747299, 'reg_lambda': 5.27805268030682}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:36,478] Trial 167 finished with value: 0.7568264868150432 and parameters: {'max_depth': 12, 'num_leaves': 146, 'n_estimators': 422, 'learning_rate': 0.20924519976218403, 'subsample': 0.7631309463108024, 'colsample_bytree': 0.6770071187173592, 'reg_lambda': 3.8381030394205826}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:38,246] Trial 168 finished with value: 0.747442514634687 and parameters: {'max_depth': 14, 'num_leaves': 103, 'n_estimators': 169, 'learning_rate': 0.12717371957973755, 'subsample': 0.8033062447972661, 'colsample_bytree': 0.6541929950198315, 'reg_lambda': 5.715193008259889}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:40,884] Trial 169 finished with value: 0.7299590439751168 and parameters: {'max_depth': 7, 'num_leaves': 126, 'n_estimators': 322, 'learning_rate': 0.2242910919247298, 'subsample': 0.7902106315507014, 'colsample_bytree': 0.6852975387872635, 'reg_lambda': 6.500891597227642}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:45,044] Trial 170 finished with value: 0.7381355627935495 and parameters: {'max_depth': 13, 'num_leaves': 133, 'n_estimators': 432, 'learning_rate': 0.2581345007682383, 'subsample': 0.7836180946421939, 'colsample_bytree': 0.818607790558602, 'reg_lambda': 9.51287403562451}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:49,924] Trial 171 finished with value: 0.7403233819142497 and parameters: {'max_depth': 15, 'num_leaves': 130, 'n_estimators': 347, 'learning_rate': 0.2451049102696898, 'subsample': 0.7774647971791652, 'colsample_bytree': 0.667875944189316, 'reg_lambda': 5.6685093506481135}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:53,070] Trial 172 finished with value: 0.7593732799100396 and parameters: {'max_depth': 15, 'num_leaves': 108, 'n_estimators': 355, 'learning_rate': 0.23699823664174047, 'subsample': 0.7805010392189581, 'colsample_bytree': 0.6707492584793249, 'reg_lambda': 5.939994875682282}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:28:56,195] Trial 173 finished with value: 0.7430530824401289 and parameters: {'max_depth': 15, 'num_leaves': 108, 'n_estimators': 359, 'learning_rate': 0.23637764866127187, 'subsample': 0.7801585772132829, 'colsample_bytree': 0.6601057991554687, 'reg_lambda': 5.9541272227351945}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:01,257] Trial 174 finished with value: 0.7564979844200735 and parameters: {'max_depth': 15, 'num_leaves': 97, 'n_estimators': 380, 'learning_rate': 0.23935526044563368, 'subsample': 0.7714849315346828, 'colsample_bytree': 0.674277557186445, 'reg_lambda': 6.339434836347664}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:04,997] Trial 175 finished with value: 0.7366051875938185 and parameters: {'max_depth': 15, 'num_leaves': 118, 'n_estimators': 368, 'learning_rate': 0.06507710930511525, 'subsample': 0.7673598622306692, 'colsample_bytree': 0.6801259632087926, 'reg_lambda': 4.13377385194895}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:07,650] Trial 176 finished with value: 0.7417859157144882 and parameters: {'max_depth': 14, 'num_leaves': 25, 'n_estimators': 332, 'learning_rate': 0.1561728705798251, 'subsample': 0.7574486506885231, 'colsample_bytree': 0.6439290729583512, 'reg_lambda': 5.35861370258137}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:13,362] Trial 177 finished with value: 0.7516859257054436 and parameters: {'max_depth': 15, 'num_leaves': 122, 'n_estimators': 448, 'learning_rate': 0.2824216769668766, 'subsample': 0.7846441114914988, 'colsample_bytree': 0.6642784968998907, 'reg_lambda': 5.033015625885718}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:16,471] Trial 178 finished with value: 0.7521052046399491 and parameters: {'max_depth': 14, 'num_leaves': 91, 'n_estimators': 355, 'learning_rate': 0.265146856870456, 'subsample': 0.7898230983419084, 'colsample_bytree': 0.6507477239908586, 'reg_lambda': 6.127064444673032}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:17,856] Trial 179 finished with value: 0.7572507877371724 and parameters: {'max_depth': 15, 'num_leaves': 114, 'n_estimators': 134, 'learning_rate': 0.25415049460011274, 'subsample': 0.7771726708605956, 'colsample_bytree': 0.6718079585750345, 'reg_lambda': 5.88897945515781}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:24,088] Trial 180 finished with value: 0.7548192474962823 and parameters: {'max_depth': 13, 'num_leaves': 106, 'n_estimators': 460, 'learning_rate': 0.14675067830748317, 'subsample': 0.7998185911506238, 'colsample_bytree': 0.6908872366810774, 'reg_lambda': 3.678723742996629}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:27,008] Trial 181 finished with value: 0.7681056035014698 and parameters: {'max_depth': 15, 'num_leaves': 32, 'n_estimators': 345, 'learning_rate': 0.24671989479586734, 'subsample': 0.7802185547975059, 'colsample_bytree': 0.6676535018150909, 'reg_lambda': 5.629314141397643}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:29,837] Trial 182 finished with value: 0.7498622326160623 and parameters: {'max_depth': 15, 'num_leaves': 32, 'n_estimators': 339, 'learning_rate': 0.231948593210175, 'subsample': 0.782502426569726, 'colsample_bytree': 0.6604530844976082, 'reg_lambda': 5.516073303291966}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:31,963] Trial 183 finished with value: 0.7461440741997667 and parameters: {'max_depth': 15, 'num_leaves': 42, 'n_estimators': 231, 'learning_rate': 0.24439790300450356, 'subsample': 0.7883961943943291, 'colsample_bytree': 0.6708513940893511, 'reg_lambda': 5.6548527225382745}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:36,948] Trial 184 finished with value: 0.7437137320065045 and parameters: {'max_depth': 15, 'num_leaves': 142, 'n_estimators': 355, 'learning_rate': 0.16596837955077526, 'subsample': 0.7749204725247265, 'colsample_bytree': 0.6555800684227416, 'reg_lambda': 5.251389798209583}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:40,139] Trial 185 finished with value: 0.7531483017882494 and parameters: {'max_depth': 14, 'num_leaves': 32, 'n_estimators': 373, 'learning_rate': 0.22697545268904756, 'subsample': 0.7791201595573741, 'colsample_bytree': 0.6655065297185307, 'reg_lambda': 5.798185546804118}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:43,064] Trial 186 finished with value: 0.7520768148639003 and parameters: {'max_depth': 8, 'num_leaves': 35, 'n_estimators': 343, 'learning_rate': 0.21737063121148534, 'subsample': 0.7933629975659159, 'colsample_bytree': 0.6809376463634451, 'reg_lambda': 6.049409776435407}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:48,336] Trial 187 finished with value: 0.750239950098118 and parameters: {'max_depth': 12, 'num_leaves': 137, 'n_estimators': 406, 'learning_rate': 0.252576962356231, 'subsample': 0.7494197051157776, 'colsample_bytree': 0.6754616513533358, 'reg_lambda': 4.01836120505601}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:49,147] Trial 188 finished with value: 0.7350038045865122 and parameters: {'max_depth': 15, 'num_leaves': 78, 'n_estimators': 70, 'learning_rate': 0.23467188172440165, 'subsample': 0.7728655334464993, 'colsample_bytree': 0.6485675114673396, 'reg_lambda': 5.3929096552535025}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:53,401] Trial 189 finished with value: 0.7290997632294538 and parameters: {'max_depth': 14, 'num_leaves': 110, 'n_estimators': 362, 'learning_rate': 0.13590803184894876, 'subsample': 0.8196549326765765, 'colsample_bytree': 0.6602236957422261, 'reg_lambda': 0.03863316205802114}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:29:57,153] Trial 190 finished with value: 0.7369601916301276 and parameters: {'max_depth': 15, 'num_leaves': 100, 'n_estimators': 390, 'learning_rate': 0.2603653519703558, 'subsample': 0.7857587832284054, 'colsample_bytree': 0.7890754095339785, 'reg_lambda': 6.291201771286008}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:02,032] Trial 191 finished with value: 0.7585170402500111 and parameters: {'max_depth': 15, 'num_leaves': 132, 'n_estimators': 346, 'learning_rate': 0.24656321764564512, 'subsample': 0.7798213481907454, 'colsample_bytree': 0.6690613955743, 'reg_lambda': 5.678367289346503}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:04,987] Trial 192 finished with value: 0.7543206694450418 and parameters: {'max_depth': 15, 'num_leaves': 134, 'n_estimators': 327, 'learning_rate': 0.24048341460211772, 'subsample': 0.7820702749690501, 'colsample_bytree': 0.6684181842156579, 'reg_lambda': 5.784981521584141}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:08,049] Trial 193 finished with value: 0.7578777123470599 and parameters: {'max_depth': 15, 'num_leaves': 128, 'n_estimators': 348, 'learning_rate': 0.24636431269534376, 'subsample': 0.7679558181402087, 'colsample_bytree': 0.6854411830254767, 'reg_lambda': 5.543842503785372}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:12,977] Trial 194 finished with value: 0.7513619380032506 and parameters: {'max_depth': 15, 'num_leaves': 128, 'n_estimators': 349, 'learning_rate': 0.2520917983473591, 'subsample': 0.7661865869099085, 'colsample_bytree': 0.6856036088966942, 'reg_lambda': 5.5214138587551425}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:15,724] Trial 195 finished with value: 0.7589586678118329 and parameters: {'max_depth': 15, 'num_leaves': 131, 'n_estimators': 312, 'learning_rate': 0.2435595622620164, 'subsample': 0.7687925482074106, 'colsample_bytree': 0.6547777095051901, 'reg_lambda': 4.690688700462965}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:18,554] Trial 196 finished with value: 0.7618817893524592 and parameters: {'max_depth': 15, 'num_leaves': 137, 'n_estimators': 306, 'learning_rate': 0.15983332439126027, 'subsample': 0.7628374336875625, 'colsample_bytree': 0.653892113225661, 'reg_lambda': 4.513306655283697}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:21,700] Trial 197 finished with value: 0.7412240084901007 and parameters: {'max_depth': 15, 'num_leaves': 139, 'n_estimators': 334, 'learning_rate': 0.16014666162528668, 'subsample': 0.7604059295074238, 'colsample_bytree': 0.6594984876960942, 'reg_lambda': 4.611633378948339}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:26,037] Trial 198 finished with value: 0.7444766024516888 and parameters: {'max_depth': 15, 'num_leaves': 135, 'n_estimators': 302, 'learning_rate': 0.25630567297549567, 'subsample': 0.7697989619602542, 'colsample_bytree': 0.6425507610920389, 'reg_lambda': 4.398342964171764}. Best is trial 124 with value: 0.7759674107629702.
# [I 2025-07-30 05:30:28,689] Trial 199 finished with value: 0.7387003507420012 and parameters: {'max_depth': 15, 'num_leaves': 149, 'n_estimators': 280, 'learning_rate': 0.16977165767984748, 'subsample': 0.763284592552438, 'colsample_bytree': 0.6645194483473795, 'reg_lambda': 4.783082608685417}. Best is trial 124 with value: 0.7759674107629702.
# Best AUC: 0.7759674107629702
# Best params: {'max_depth': 15, 'num_leaves': 138, 'n_estimators': 332, 'learning_rate': 0.281393510469453, 'subsample': 0.7545781389603842, 'colsample_bytree': 0.6602598373388076, 'reg_lambda': 3.870660430860955}

# %%
def expanding_window_cv(X, y,
                        init_frac=0.3,
                        val_frac=0.14,
                        n_folds=5,
                        random_state=42):
   
    n = len(y)
    init_window = int(np.floor(init_frac * n))
    val_window  = int(np.floor(val_frac  * n))

    accuracies = []
    aucs       = []

    lgbm_params = {
        'objective':        'binary',
        'is_unbalance':     True,
        'n_estimators':     332,
        'learning_rate':    0.281393510469453,
        'num_leaves':       138,
        'max_depth':        15,
        'subsample':        0.7545781389603842,
        'colsample_bytree': 0.6602598373388076,
        'subsample_freq':   1,
        'reg_alpha':        0.0,
        'reg_lambda':       3.870660430860955,
        'random_state':     random_state,
        'verbose':          -1,
        'n_jobs':           -1
    }

    for fold in range(n_folds):
        train_end = init_window + fold * val_window
        val_start = train_end
        val_end   = val_start + val_window
        if val_end > n:
            break  

        X_tr = X[:train_end-63]
        y_tr = y[:train_end-63]
        X_val = X[val_start:val_end]
        y_val = y[val_start:val_end]

        clf = lgb.LGBMClassifier(**lgbm_params)
        clf.fit(X_tr, y_tr)

        y_pred  = clf.predict(X_val)
        y_proba = clf.predict_proba(X_val)[:, 1]
        acc = accuracy_score(y_val, y_pred)
        auc = roc_auc_score(y_val, y_proba)

        accuracies.append(acc)
        aucs.append(auc)

        print(f"Fold {fold+1:2d} — train up to {train_end:4d}, "
              f"valid [{val_start:4d}:{val_end:4d}]  "
              f"→ Acc: {acc:.4f}, AUC: {auc:.4f}")

    mean_acc = np.mean(accuracies)
    mean_auc = np.mean(aucs)
    print(f"\nOverall CV → Mean Accuracy: {mean_acc:.4f}, Mean AUC: {mean_auc:.4f}")

    return mean_acc, mean_auc

mean_accuracy, mean_auc = expanding_window_cv(
    X_train[selected_feats].ffill(),
    y_train
)
# Out:
# Fold  1 — train up to  930, valid [ 930:1364]  → Acc: 0.6682, AUC: 0.7160
# Fold  2 — train up to 1364, valid [1364:1798]  → Acc: 0.7074, AUC: 0.7863
# Fold  3 — train up to 1798, valid [1798:2232]  → Acc: 0.7696, AUC: 0.7697
# Fold  4 — train up to 2232, valid [2232:2666]  → Acc: 0.6544, AUC: 0.7681
# Fold  5 — train up to 2666, valid [2666:3100]  → Acc: 0.6313, AUC: 0.8397
#
# Overall CV → Mean Accuracy: 0.6862, Mean AUC: 0.7760

# %% [markdown]
# <font size=4, font color='blue'> Holdout test set performance (model refitted on the complete training set)

# %%
model = lgb.LGBMClassifier(
        objective='binary',
        is_unbalance=True,
        n_estimators=332,
        learning_rate= 0.281393510469453,
        num_leaves=138,
        max_depth=15,
        subsample=0.7545781389603842,
        colsample_bytree= 0.6602598373388076,
        subsample_freq=1,
        reg_alpha=0.0,
        reg_lambda=3.870660430860955,
        random_state=42,
        verbose=-1,
        n_jobs=-1
)

model.fit(
    X_train[selected_feats].ffill().iloc[:-63], y_train[:-63],
    eval_metric='binary_logloss',
)

y_pred = model.predict(X_test[selected_feats])
y_proba = model.predict_proba(X_test[selected_feats])[:, 1]

auroc = roc_auc_score(y_test, y_proba)
print(f'Test AUROC: {auroc:.4f}')

print("Test Accuracy: ", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

importances = pd.Series(model.feature_importances_, index=X_train[selected_feats].columns)
print("\nTop 10 features by importance:")
print(importances.sort_values(ascending=False).head(10))
# Out:
# Test AUROC: 0.7105
# Test Accuracy:  0.663659793814433
#               precision    recall  f1-score   support
#
#            0       0.63      0.81      0.71       395
#            1       0.72      0.51      0.60       381
#
#     accuracy                           0.66       776
#    macro avg       0.68      0.66      0.65       776
# weighted avg       0.68      0.66      0.66       776
#
#
# Top 10 features by importance:
# P/C_Index_pct21      614
# n_gas_vol_pct14      556
# TPU_pct42            541
# 10Y-2Y_diff21        526
# BDI_pct21            494
# soybean_std7         482
# VIX_std21            472
# Russell_vol_std42    471
# shopping_pct14       457
# soybean_vol_std14    455
# dtype: int32

# %% [markdown]
# <font size=4, font color='blue'> All feature importances

# %%
importances.sort_values(ascending=False)
# Out:
# P/C_Index_pct21                   614
# n_gas_vol_pct14                   556
# TPU_pct42                         541
# 10Y-2Y_diff21                     526
# BDI_pct21                         494
# soybean_std7                      482
# VIX_std21                         472
# Russell_vol_std42                 471
# shopping_pct14                    457
# soybean_vol_std14                 455
# Bond_pct7                         446
# gold_pct42                        445
# soybean_vol_mean21                445
# Bond_ret_std14                    433
# 10Y-2Y                            433
# P/C_Equity_mean14                 423
# BDI_pct7                          419
# gold_vol_mean21                   414
# oil_vol_mean42                    406
# level                             396
# EPU_mean42                        392
# silver_std21                      389
# Bullish_std8                      386
# Bullish_mean4                     380
# GSCPI_diff2                       380
# 5 Yr                              380
# silver_std42                      370
# P/C_Equity_std21                  368
# soybean_vol_std42                 368
# VVIX_mean42                       355
# Bond_pct14                        355
# gold_vol_std42                    346
# Investment Grade OAS14            338
# infl_a                            337
# copper_vol_mean42                 337
# oil_vol_std42                     334
# infl_a3                           315
# Industry_Production_Index_pct2    315
# n_gas_vol_std42                   312
# infl_q_diff                       292
# dtype: int32
